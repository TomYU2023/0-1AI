# %% [markdown]
# 假如我要跟你取得联系，需要以下信息：
# ip地址：你家住址(ipv4：4个8位二进制，0~255; ipv6：8个16位二进制，0~65535)
# 端口：哪个应用程序(知名端口：0~1023（常用的）； 动态端口：1024~65535（开发用的）)
# 协议：说哪国语？（TCP：可靠，慢；UDP：不可靠，快）

# %% [markdown]
# Linux、Mac ifconfig
# Windows ipconfig
# 查看ip地址

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 检查网络是否正常使用 ping 命令
# - ping www.baidu.com 检查是否能上公网
# - ping 当前局域网的ip地址 检查是否在同一个局域网内
# - ping 127.0.0.1 检查本地网卡是否正常

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 建立通讯3步骤

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 断开连接4步骤

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TCP4层协议内部构造
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 早年的协议OSI

# %% [markdown]
# ![image.png](attachment:image.png)
